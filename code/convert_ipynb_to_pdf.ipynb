# %%
# Installation de TeX Live (distribution LaTeX)
# !apt-get install texlive-xetex

# %%
# Importing working libraries
import os

# Select your development environment
environment = "Google Colab" # "Google Colab", "Local"

# Loading depending on environment
project_path = ""
if environment == "Google Colab":
  from google.colab import drive
  # Import from my google drive
  drive.mount('/content/drive')
  project_path = "/content/drive/MyDrive/Colab Notebooks/UAB Project/Machine Learning/Project/UAB23-Machine-Learning-Project"
else:
  project_path = "./"

# path_notebook = os.path.join(project_path,"code","preliminary_analysis_and_cleaning_of_the_dataset.ipynb")
# path_pdf = os.path.join(project_path,"code","preliminary_analysis_and_cleaning_of_the_dataset.pdf")

path_notebook = os.path.join(project_path,"code","training_and_performance_evaluation_of_models.ipynb")
path_pdf = os.path.join(project_path,"code","training_and_performance_evaluation_of_models.pdf")

# Utilisez la commande nbconvert en spécifiant les chemins en tant qu'arguments
# !jupyter nbconvert --to pdf "{path_notebook}" --output "{path_pdf}"
